# %%
# %pip install python-pptx
# Out:
# Requirement already satisfied: python-pptx in /home/sergey/miniconda3/lib/python3.12/site-packages (1.0.2)
# Requirement already satisfied: Pillow>=3.3.2 in /home/sergey/miniconda3/lib/python3.12/site-packages (from python-pptx) (10.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/sergey/miniconda3/lib/python3.12/site-packages (from python-pptx) (3.2.9)
# Requirement already satisfied: lxml>=3.1.0 in /home/sergey/miniconda3/lib/python3.12/site-packages (from python-pptx) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/sergey/miniconda3/lib/python3.12/site-packages (from python-pptx) (4.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pptx import Presentation

# %%
image_path = 'Рисунок4.jpg'

# %%
prs = Presentation('04_1.pptx')
slides = prs.slides
len(slides)
# Out:
# 1

# %%
slide = slides[0]

# %%
len(prs.slide_layouts)
# Out:
# 1

# %%
# Получаем объект макета, применённый к слайду
layout = slide.slide_layout

# %%
# Выводим имя макета (если доступно)
print("Имя макета:", layout.name)
# Выводим индекс макета в коллекции slide_layouts
#print("Индекс макета:", layout.idx)
# Out:
# Имя макета: Заголовок и объект

# %%
for shape in slide.shapes:
    # Проверка типа элемента
    if shape.has_text_frame:
        print(f"На слайде есть текстовый элемент: {shape.text}", shape.name, shape.shape_type)
    elif shape.shape_type == MSO_SHAPE.PICTURE:
         print("На слайде есть изображение")
    # Можно добавить проверки для других типов элементов
    else:
      print(f"Найден элемент типа: {shape.shape_type}")
# Out:
# На слайде есть текстовый элемент:  Заголовок 1 PLACEHOLDER (14)
# На слайде есть текстовый элемент:  Нижний колонтитул 2 PLACEHOLDER (14)
# На слайде есть текстовый элемент: 1 Номер слайда 3 PLACEHOLDER (14)
# На слайде есть текстовый элемент:  Текст 4 PLACEHOLDER (14)
# На слайде есть текстовый элемент:  Текст 5 PLACEHOLDER (14)

# %%
len(slide.placeholders)
# Out:
# 5

# %%
for shape in slide.placeholders:
    print(f"Индекс: {shape.placeholder_format.idx}, Тип: {shape.placeholder_format.type}")
# Out:
# Индекс: 0, Тип: TITLE (1)
# Индекс: 4, Тип: SLIDE_NUMBER (13)
# Индекс: 11, Тип: FOOTER (15)
# Индекс: 12, Тип: BODY (2)
# Индекс: 13, Тип: BODY (2)

# %%
"""for placeholder in slide.placeholders:
    # Проверка типа элемента
    if placeholder.has_text_frame:
        #print(f"На слайде есть текстовый элемент: {placeholder.text}", placeholder.name)
        print(placeholder.name)"""
# Out:
# 'for placeholder in slide.placeholders:\n    # Проверка типа элемента\n    if placeholder.has_text_frame:\n        #print(f"На слайде есть текстовый элемент: {placeholder.text}", placeholder.name)\n        print(placeholder.name)'

# %%
for i in range(len(slide.shapes)):
    print(i)
    slide.shapes[i].text_frame.text = f'Индекс {i}'
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
slide = prs.slides.add_slide(layout)

# %%
for i in range(len(slide.shapes)):
    print(i)
    slide.shapes[i].text_frame.text = f'Индекс {i}'
# Out:
# 0
# 1
# 2

# %%
slide.shapes[2].text_frame.text = 'Заголовок'
slide.shapes[3].text_frame.text = 'Подпись к фото 1'
slide.shapes[4].text_frame.text = 'Подпись к фото 2'
# Найдите нужный Placeholder, например, по типу или индексу
placeholder = slide.shapes[0] # Уточните индекс или найдите по типу

# Добавьте изображение с координатами и размерами Placeholder
slide.shapes.add_picture(image_path, placeholder.left, placeholder.top, placeholder.width) #, placeholder.height)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pptx/shapes/shapetree.py:92, in _BaseShapes.__getitem__(self, idx)
#      91 try:
# ---> 92     shape_elm = shape_elms[idx]
#      93 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[120], line 2
#       1 slide.shapes[2].text_frame.text = 'Заголовок'
# ----> 2 slide.shapes[3].text_frame.text = 'Подпись к фото 1'
#       3 slide.shapes[4].text_frame.text = 'Подпись к фото 2'
#       4 # Найдите нужный Placeholder, например, по типу или индексу
#
# File ~/miniconda3/lib/python3.12/site-packages/pptx/shapes/shapetree.py:94, in _BaseShapes.__getitem__(self, idx)
#      92     shape_elm = shape_elms[idx]
#      93 except IndexError:
# ---> 94     raise IndexError("shape index out of range")
#      95 return self._shape_factory(shape_elm)
#
# IndexError: shape index out of range

# %%
prs.save('output.pptx')

# %%
len(slide.placeholders)
# Out:
# 3

# %%
for shape in slide.placeholders:
    print(f"Индекс: {shape.placeholder_format.idx}, Тип: {shape.placeholder_format.type}")
# Out:
# Индекс: 0, Тип: TITLE (1)
# Индекс: 12, Тип: BODY (2)
# Индекс: 13, Тип: BODY (2)

# %%
for i in range(len(prs.slide_layouts)):
    print(i, prs.slide_layouts[i].name)
# Out:
# 0 Заголовок и объект

# %%
help(prs.slides.add_slide)
# Out:
# Help on method add_slide in module pptx.slide:
#
# add_slide(slide_layout: 'SlideLayout') -> 'Slide' method of pptx.slide.Slides instance
#     Return a newly added slide that inherits layout from `slide_layout`.

# %%
slide.shapes[0].left, slide.shapes[0].top, slide.shapes[0].width, slide.shapes[0].height
# Out:
# (520383, 292059, 11155680, 590931)

# %%
slide.shapes[1].left, slide.shapes[1].top, slide.shapes[1].width, slide.shapes[1].height
# Out:
# (515937, 988220, 5440481, 1028564)
